# %%
import pandas as pd
import os

# %% [markdown]
# ### data_file will not be kept in repo. Too large for github upload.

# %%
# Assign data file path
data_file = '../../assets/data/raw_samples/query_181021%2F000000000000.csv'
sample_file = '../../assets/data/raw_samples/query_181021_sample.csv'
chunk_size = 10 ** 6

df_head = pd.read_csv(data_file).sample(n=20)

df_head.head(5)
# Out:
#         score  favorite_count  view_count  answer_count  \
# 44272       8             1.0       16541             3
# 67101      12             2.0       30494             5
# 27576       5             1.0        2564             1
# 122593    120            75.0       91011             6
# 111155    110            10.0      156528             2
#
#                                                      link  \
# 44272   https://stackoverflow.com/questions/2739627/jq...
# 67101   https://stackoverflow.com/questions/4745311/c-...
# 27576   https://stackoverflow.com/questions/25278955/s...
# 122593  https://stackoverflow.com/questions/14968297/u...
# 111155  https://stackoverflow.com/questions/6305225/ho...
#
#                                                     title  \
# 44272   jQuery: preventDefault() not working on input/...
# 67101                                   c++ division by 0
# 27576                         sequelize validation method
# 122593          Use underscore inside Angular controllers
# 111155  How to add not null constraint to existing col...
#
#                                                      body  \
# 44272   <p>I want to disable the default contextMenu w...
# 67101   <p>I am running long simulations. I record the...
# 27576   <p>I'm trying to validate my Model but i miss ...
# 122593  <p>How do I use underscore library inside angu...
# 111155  <p>I have table name called "Person" with foll...
#
#                                          tags
# 44272   jquery|events|right-click|input-field
# 67101                      c++|divide-by-zero
# 27576           validation|email|sequelize.js
# 122593     javascript|angularjs|underscore.js
# 111155                      mysql|constraints

# %%
# Chunk and keep 1/5 of data
df_chunked = pd.read_csv(data_file, skiprows=lambda x: x % 5, chunksize=chunk_size)

# Write the kept half to a sample csv file
for chunk in df_chunked:
    if os.path.isfile(sample_file):  # check if file already exists
        chunk.to_csv(sample_file, mode='a', header=False)
    else:
        chunk.to_csv(sample_file)

# %%
sample_df = pd.read_csv(sample_file, nrows=20)
sample_df.head(5)
# Out:
#    Unnamed: 0  score  favorite_count  view_count  answer_count  \
# 0           0      5             NaN        1711             4
# 1           1      5             NaN       13285             3
# 2           2      5             NaN       14437             1
# 3           3      5             NaN         158             5
# 4           4      5             NaN         842             1
#
#                                                 link  \
# 0  https://stackoverflow.com/questions/2577911/c-...
# 1  https://stackoverflow.com/questions/3069448/ho...
# 2  https://stackoverflow.com/questions/17144405/s...
# 3  https://stackoverflow.com/questions/48735618/i...
# 4  https://stackoverflow.com/questions/29913935/c...
#
#                                                title  \
# 0               C++ vector pointer/reference problem
# 1                How to declare a void pointer in C#
# 2            SSIS OLEDB destination with SQL command
# 3  Is this the correct way of writing an array of...
# 4  Can I enable hardware acceleration for Angular...
#
#                                                 body  \
# 0  <p>Please take a look at this example:</p>\n\n...
# 1    <p>How can we declare a void pointer in C#?</p>
# 2  <p>I have a simple SSIS package with a data fl...
# 3  <p>I have a class "Employee"\nI want to create...
# 4  <p>The current version does not seem smooth an...
#
#                                                tags
# 0                               c++|vector|pointers
# 1                                    c#|c#-4.0|void
# 2                    sql|sql-server-2008|ssis|oledb
# 3                                               c++
# 4  angularjs|hardware-acceleration|angular-material
